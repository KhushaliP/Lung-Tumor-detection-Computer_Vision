# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load = nib.load('D:/projects/CV/feta_2.2/sub-056/anat/sub-056_rec-irtk_T2w.nii.gz').get_fdata()

test_load.shape
# Out:
# (256, 256, 256)

# %% [markdown]
# By loading it in nib, we get a  "slice"

# %%
test_img = test_load[:, :, 80]
plt.figure(figsize=(10,10))
plt.imshow(test_img)
plt.show()
